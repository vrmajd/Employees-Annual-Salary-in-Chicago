# %%
import pandas as pd
df=pd.read_csv("Mydatasets/salary.csv")

# %%
df.head()
# Out:
#                   Name                              Job Titles   Department  \
# 0    AARON,  JEFFERY M                                SERGEANT       POLICE
# 1       AARON,  KARINA  POLICE OFFICER (ASSIGNED AS DETECTIVE)       POLICE
# 2  ABAD JR,  VICENTE M                       CIVIL ENGINEER IV  WATER MGMNT
# 3    ABARCA,  EMMANUEL                        CONCRETE LABORER   TRANSPORTN
# 4   ABARCA,  FRANCES J                          POLICE OFFICER       POLICE
#
#   Full or Part-Time Salary or Hourly  Typical Hours  Annual Salary  \
# 0                 F           Salary            NaN       122568.0
# 1                 F           Salary            NaN       110796.0
# 2                 F           Salary            NaN       122112.0
# 3                 F           Hourly           40.0            NaN
# 4                 F           Salary            NaN        86730.0
#
#    Hourly Rate
# 0          NaN
# 1          NaN
# 2          NaN
# 3         45.9
# 4          NaN

# %%
df.tail()
# Out:
#                       Name               Job Titles Department  \
# 31096   ZYLINSKA,  KLAUDIA           POLICE OFFICER     POLICE
# 31097   ZYMANTAS,  LAURA C           POLICE OFFICER     POLICE
# 31098    ZYMANTAS,  MARK E           POLICE OFFICER     POLICE
# 31099  ZYRKOWSKI,  CARLO E           POLICE OFFICER     POLICE
# 31100  ZYSKOWSKI,  DARIUSZ  CHIEF DATA BASE ANALYST       DAIS
#
#       Full or Part-Time Salary or Hourly  Typical Hours  Annual Salary  \
# 31096                 F           Salary            NaN        90990.0
# 31097                 F           Salary            NaN        95586.0
# 31098                 F           Salary            NaN       102372.0
# 31099                 F           Salary            NaN       109236.0
# 31100                 F           Salary            NaN       142176.0
#
#        Hourly Rate
# 31096          NaN
# 31097          NaN
# 31098          NaN
# 31099          NaN
# 31100          NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31101 entries, 0 to 31100
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               31101 non-null  object
#  1   Job Titles         31101 non-null  object
#  2   Department         31101 non-null  object
#  3   Full or Part-Time  31101 non-null  object
#  4   Salary or Hourly   31101 non-null  object
#  5   Typical Hours      6814 non-null   float64
#  6   Annual Salary      24287 non-null  float64
#  7   Hourly Rate        6814 non-null   float64
# dtypes: float64(3), object(5)
# memory usage: 1.9+ MB

# %%
df.describe()
# Out:
#        Typical Hours  Annual Salary  Hourly Rate
# count    6814.000000   24287.000000  6814.000000
# mean       36.476372   98750.838941    38.851099
# std         8.221823   22459.971347    12.978368
# min        10.000000   21600.000000     3.000000
# 25%        40.000000   86730.000000    34.547500
# 50%        40.000000   98940.000000    39.250000
# 75%        40.000000  109236.000000    49.300000
# max        40.000000  275004.000000   134.400000

# %%
df.head(1)
# Out:
#                 Name Job Titles Department Full or Part-Time Salary or Hourly  \
# 0  AARON,  JEFFERY M   SERGEANT     POLICE                 F           Salary
#
#    Typical Hours  Annual Salary  Hourly Rate
# 0            NaN       122568.0          NaN

# %%
df.Name
# Out:
# 0          AARON,  JEFFERY M
# 1             AARON,  KARINA
# 2        ABAD JR,  VICENTE M
# 3          ABARCA,  EMMANUEL
# 4         ABARCA,  FRANCES J
#                 ...
# 31096     ZYLINSKA,  KLAUDIA
# 31097     ZYMANTAS,  LAURA C
# 31098      ZYMANTAS,  MARK E
# 31099    ZYRKOWSKI,  CARLO E
# 31100    ZYSKOWSKI,  DARIUSZ
# Name: Name, Length: 31101, dtype: object

# %%
df[["Name"]]
# Out:
#                       Name
# 0        AARON,  JEFFERY M
# 1           AARON,  KARINA
# 2      ABAD JR,  VICENTE M
# 3        ABARCA,  EMMANUEL
# 4       ABARCA,  FRANCES J
# ...                    ...
# 31096   ZYLINSKA,  KLAUDIA
# 31097   ZYMANTAS,  LAURA C
# 31098    ZYMANTAS,  MARK E
# 31099  ZYRKOWSKI,  CARLO E
# 31100  ZYSKOWSKI,  DARIUSZ
#
# [31101 rows x 1 columns]

# %%
df[["Name","Job Titles","Department"]]
# Out:
#                       Name                              Job Titles  \
# 0        AARON,  JEFFERY M                                SERGEANT
# 1           AARON,  KARINA  POLICE OFFICER (ASSIGNED AS DETECTIVE)
# 2      ABAD JR,  VICENTE M                       CIVIL ENGINEER IV
# 3        ABARCA,  EMMANUEL                        CONCRETE LABORER
# 4       ABARCA,  FRANCES J                          POLICE OFFICER
# ...                    ...                                     ...
# 31096   ZYLINSKA,  KLAUDIA                          POLICE OFFICER
# 31097   ZYMANTAS,  LAURA C                          POLICE OFFICER
# 31098    ZYMANTAS,  MARK E                          POLICE OFFICER
# 31099  ZYRKOWSKI,  CARLO E                          POLICE OFFICER
# 31100  ZYSKOWSKI,  DARIUSZ                 CHIEF DATA BASE ANALYST
#
#         Department
# 0           POLICE
# 1           POLICE
# 2      WATER MGMNT
# 3       TRANSPORTN
# 4           POLICE
# ...            ...
# ...

# %%
df.head(2)
# Out:
#                 Name                              Job Titles Department  \
# 0  AARON,  JEFFERY M                                SERGEANT     POLICE
# 1     AARON,  KARINA  POLICE OFFICER (ASSIGNED AS DETECTIVE)     POLICE
#
#   Full or Part-Time Salary or Hourly  Typical Hours  Annual Salary  \
# 0                 F           Salary            NaN       122568.0
# 1                 F           Salary            NaN       110796.0
#
#    Hourly Rate
# 0          NaN
# 1          NaN

# %%
df.iloc[0]
# Out:
# Name                 AARON,  JEFFERY M
# Job Titles                    SERGEANT
# Department                      POLICE
# Full or Part-Time                    F
# Salary or Hourly                Salary
# Typical Hours                      NaN
# Annual Salary                   122568
# Hourly Rate                        NaN
# Name: 0, dtype: object

# %%
df.iloc[0:5]
# Out:
#                   Name                              Job Titles   Department  \
# 0    AARON,  JEFFERY M                                SERGEANT       POLICE
# 1       AARON,  KARINA  POLICE OFFICER (ASSIGNED AS DETECTIVE)       POLICE
# 2  ABAD JR,  VICENTE M                       CIVIL ENGINEER IV  WATER MGMNT
# 3    ABARCA,  EMMANUEL                        CONCRETE LABORER   TRANSPORTN
# 4   ABARCA,  FRANCES J                          POLICE OFFICER       POLICE
#
#   Full or Part-Time Salary or Hourly  Typical Hours  Annual Salary  \
# 0                 F           Salary            NaN       122568.0
# 1                 F           Salary            NaN       110796.0
# 2                 F           Salary            NaN       122112.0
# 3                 F           Hourly           40.0            NaN
# 4                 F           Salary            NaN        86730.0
#
#    Hourly Rate
# 0          NaN
# 1          NaN
# 2          NaN
# 3         45.9
# 4          NaN

# %%
df.iloc[[0,17,48]]
# Out:
#                         Name                 Job Titles   Department  \
# 0          AARON,  JEFFERY M                   SERGEANT       POLICE
# 17  ABDUL-KARIM,  MUHAMMAD A  ENGINEERING TECHNICIAN VI  WATER MGMNT
# 48           ADAMS,  BRIAN K    LAMP MAINTENANCE WORKER   TRANSPORTN
#
#    Full or Part-Time Salary or Hourly  Typical Hours  Annual Salary  \
# 0                  F           Salary            NaN       122568.0
# 17                 F           Salary            NaN       123696.0
# 48                 F           Hourly           40.0            NaN
#
#     Hourly Rate
# 0           NaN
# 17          NaN
# 48        35.29

# %%
df.iloc[[-1]]
# Out:
#                       Name               Job Titles Department  \
# 31100  ZYSKOWSKI,  DARIUSZ  CHIEF DATA BASE ANALYST       DAIS
#
#       Full or Part-Time Salary or Hourly  Typical Hours  Annual Salary  \
# 31100                 F           Salary            NaN       142176.0
#
#        Hourly Rate
# 31100          NaN

# %%
df.iloc[0,1]
# Out:
# 'SERGEANT'

# %%
df.iloc[0,0:4]
# Out:
# Name                 AARON,  JEFFERY M
# Job Titles                    SERGEANT
# Department                      POLICE
# Full or Part-Time                    F
# Name: 0, dtype: object

# %%
df.iloc[0,[1,2,5,6]]
# Out:
# Job Titles       SERGEANT
# Department         POLICE
# Typical Hours         NaN
# Annual Salary      122568
# Name: 0, dtype: object

# %%
df.iloc[:,[1,5,6]]
# Out:
#                                    Job Titles  Typical Hours  Annual Salary
# 0                                    SERGEANT            NaN       122568.0
# 1      POLICE OFFICER (ASSIGNED AS DETECTIVE)            NaN       110796.0
# 2                           CIVIL ENGINEER IV            NaN       122112.0
# 3                            CONCRETE LABORER           40.0            NaN
# 4                              POLICE OFFICER            NaN        86730.0
# ...                                       ...            ...            ...
# 31096                          POLICE OFFICER            NaN        90990.0
# 31097                          POLICE OFFICER            NaN        95586.0
# 31098                          POLICE OFFICER            NaN       102372.0
# 31099                          POLICE OFFICER            NaN       109236.0
# 31100                 CHIEF DATA BASE ANALYST            NaN       142176.0
#
# [31101 rows x 3 columns]

# %%
df.iloc[[0,17,48],[0,1,4,5,6]]
# Out:
#                         Name                 Job Titles Salary or Hourly  \
# 0          AARON,  JEFFERY M                   SERGEANT           Salary
# 17  ABDUL-KARIM,  MUHAMMAD A  ENGINEERING TECHNICIAN VI           Salary
# 48           ADAMS,  BRIAN K    LAMP MAINTENANCE WORKER           Hourly
#
#     Typical Hours  Annual Salary
# 0             NaN       122568.0
# 17            NaN       123696.0
# 48           40.0            NaN
